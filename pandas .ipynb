# %%
import pandas as pd

# %%
df = pd.read_csv('Desktop/sales_record.csv')

# %%
df
# Out:
#     Distributor ID   Distributor Name                       Country  \
# 0            23345       Devin Abbott                        France
# 1            23278  Aphrodite Brennan                        Malawi
# 2            23303      Guinevere Key                      Colombia
# 3            23353       Zahir Fields                        Canada
# 4            23289       Deacon Craig                      Mongolia
# 5            23378     Brynne Mcgowan                       Finland
# 6            23283         Lani Sweet                       Vanuatu
# 7            23324       Noble Warner                  Burkina Faso
# 8            23264       Levi Douglas  Tanzania, United Republic of
# 9            23291    Jelani Odonnell                       Albania
# 10           23305     Jared Sandoval                      Botswana
# 11           23350     Hiroko Acevedo                       Burundi
# 12           23300       Rhona Clarke                      Zimbabwe
# ...

# %%
df.head(10)
# Out:
#    Distributor ID   Distributor Name                       Country  \
# 0           23345       Devin Abbott                        France
# 1           23278  Aphrodite Brennan                        Malawi
# 2           23303      Guinevere Key                      Colombia
# 3           23353       Zahir Fields                        Canada
# 4           23289       Deacon Craig                      Mongolia
# 5           23378     Brynne Mcgowan                       Finland
# 6           23283         Lani Sweet                       Vanuatu
# 7           23324       Noble Warner                  Burkina Faso
# 8           23264       Levi Douglas  Tanzania, United Republic of
# 9           23291    Jelani Odonnell                       Albania
#
#   Product Code                         Product Sales Channel  Date Sold  \
# 0      SUPA105      Super Soft Bulk - 2 Litres        Online      41150
# 1      SUPA105      Super Soft Bulk - 2 Litres        Direct      41145
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Distributor ID    29 non-null     int64
#  1   Distributor Name  29 non-null     object
#  2   Country           29 non-null     object
#  3   Product Code      29 non-null     object
#  4   Product           29 non-null     object
#  5   Sales Channel     29 non-null     object
#  6   Date Sold         29 non-null     int64
#  7   Month Sold        29 non-null     int64
#  8   Quantity          29 non-null     int64
#  9   Unit Price        29 non-null     float64
#  10  Revenue           29 non-null     float64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 2.6+ KB

# %%
df.describe()
# Out:
#        Distributor ID     Date Sold  Month Sold    Quantity  Unit Price  \
# count       29.000000     29.000000   29.000000   29.000000   29.000000
# mean     23316.793103  41070.172414    5.793103  163.724138   10.360000
# std         31.028074     88.103863    2.807888   34.909983    3.082857
# min      23264.000000  40911.000000    1.000000   73.000000    4.500000
# 25%      23291.000000  41070.000000    6.000000  142.000000    9.000000
# 50%      23314.000000  41088.000000    6.000000  168.000000    9.000000
# 75%      23345.000000  41136.000000    8.000000  188.000000   14.500000
# max      23378.000000  41150.000000    8.000000  208.000000   14.500000
#
#            Revenue
# count    29.000000
# mean   1670.259655
# std     569.724864
# min     913.500000
# 25%    1269.000000
# 50%    1530.000000
# 75%    1928.070000
# max    3016.000000

# %% [markdown]
# # creating DataFrames

# %%
#specify values for each column

df = pd.DataFrame({'products':['rice', 'garri', 'semo', 'yam', 'beans', 'bread', 'potatoes', 'plaintain', 'cocoyam','milo', 'cowbell', 'bournvita', 'pepsi', 'egg', 'tomatoes', 'pepper', 'malt','coke', 'maize', 'fish', 'goatmeat'],
     'unit_price':[1400,4000,800,2000,1200,1500,1200,500,3500,1800,1500,2500,3200,3400,6000,6500,4500,3500,15000,10500,25000],
     'quantity_sold':[85,65,30,60,45,150,80,24,30,81,75,65,95,48,59,63,21,80,25,50,35],
     'revenue':[119000,260000,24000,120000,54000,225000,96000,12000,105000,145800,112500,162500,304000,163200,354000,409500,94500,280000,375000,525000,875000]})

# %%
df
# Out:
#      products  unit_price  quantity_sold  revenue
# 0        rice        1400             85   119000
# 1       garri        4000             65   260000
# 2        semo         800             30    24000
# 3         yam        2000             60   120000
# 4       beans        1200             45    54000
# 5       bread        1500            150   225000
# 6    potatoes        1200             80    96000
# 7   plaintain         500             24    12000
# 8     cocoyam        3500             30   105000
# 9        milo        1800             81   145800
# 10    cowbell        1500             75   112500
# 11  bournvita        2500             65   162500
# 12      pepsi        3200             95   304000
# 13        egg        3400             48   163200
# 14   tomatoes        6000             59   354000
# 15     pepper        6500             63   409500
# 16       malt        4500             21    94500
# 17       coke        3500             80   280000
# ...

# %%
df.head(4)
# Out:
#   products  unit_price  quantity_sold  revenue
# 0     rice        1400             85   119000
# 1    garri        4000             65   260000
# 2     semo         800             30    24000
# 3      yam        2000             60   120000

# %% [markdown]
# # Reshaping Data – Change layout, sorting, reindexing, renaming

# %%
pd.melt(df)
# Out:
#     variable   value
# 0   products    rice
# 1   products   garri
# 2   products    semo
# 3   products     yam
# 4   products   beans
# ..       ...     ...
# 79   revenue   94500
# 80   revenue  280000
# 81   revenue  375000
# 82   revenue  525000
# 83   revenue  875000
#
# [84 rows x 2 columns]

# %%
df.pivot(columns = 'products', values = 'revenue' )
# Out:
# products    beans  bournvita     bread   cocoyam      coke   cowbell  \
# 0             NaN        NaN       NaN       NaN       NaN       NaN
# 1             NaN        NaN       NaN       NaN       NaN       NaN
# 2             NaN        NaN       NaN       NaN       NaN       NaN
# 3             NaN        NaN       NaN       NaN       NaN       NaN
# 4         54000.0        NaN       NaN       NaN       NaN       NaN
# 5             NaN        NaN  225000.0       NaN       NaN       NaN
# 6             NaN        NaN       NaN       NaN       NaN       NaN
# 7             NaN        NaN       NaN       NaN       NaN       NaN
# 8             NaN        NaN       NaN  105000.0       NaN       NaN
# 9             NaN        NaN       NaN       NaN       NaN       NaN
# 10            NaN        NaN       NaN       NaN       NaN  112500.0
# 11            NaN   162500.0       NaN       NaN       NaN       NaN
# 12            NaN        NaN       NaN       NaN       NaN       NaN
# ...

# %%
df.sort_values('quantity_sold')
#Order rows by values of a column (low to high).
# Out:
#      products  unit_price  quantity_sold  revenue
# 16       malt        4500             21    94500
# 7   plaintain         500             24    12000
# 18      maize       15000             25   375000
# 2        semo         800             30    24000
# 8     cocoyam        3500             30   105000
# 20   goatmeat       25000             35   875000
# 4       beans        1200             45    54000
# 13        egg        3400             48   163200
# 19       fish       10500             50   525000
# 14   tomatoes        6000             59   354000
# 3         yam        2000             60   120000
# 15     pepper        6500             63   409500
# 1       garri        4000             65   260000
# 11  bournvita        2500             65   162500
# 10    cowbell        1500             75   112500
# 6    potatoes        1200             80    96000
# 17       coke        3500             80   280000
# 9        milo        1800             81   145800
# ...

# %%
df.sort_values('unit_price', ascending=False)
# Out:
#      products  unit_price  quantity_sold  revenue
# 20   goatmeat       25000             35   875000
# 18      maize       15000             25   375000
# 19       fish       10500             50   525000
# 15     pepper        6500             63   409500
# 14   tomatoes        6000             59   354000
# 16       malt        4500             21    94500
# 1       garri        4000             65   260000
# 17       coke        3500             80   280000
# 8     cocoyam        3500             30   105000
# 13        egg        3400             48   163200
# 12      pepsi        3200             95   304000
# 11  bournvita        2500             65   162500
# 3         yam        2000             60   120000
# 9        milo        1800             81   145800
# 10    cowbell        1500             75   112500
# 5       bread        1500            150   225000
# 0        rice        1400             85   119000
# 6    potatoes        1200             80    96000
# ...

# %%
df.rename(columns = {'products':'consumables'})
#Rename the columns of a DataFrame
# Out:
#    consumables  unit_price  quantity_sold  revenue
# 0         rice        1400             85   119000
# 1        garri        4000             65   260000
# 2         semo         800             30    24000
# 3          yam        2000             60   120000
# 4        beans        1200             45    54000
# 5        bread        1500            150   225000
# 6     potatoes        1200             80    96000
# 7    plaintain         500             24    12000
# 8      cocoyam        3500             30   105000
# 9         milo        1800             81   145800
# 10     cowbell        1500             75   112500
# 11   bournvita        2500             65   162500
# 12       pepsi        3200             95   304000
# 13         egg        3400             48   163200
# 14    tomatoes        6000             59   354000
# 15      pepper        6500             63   409500
# 16        malt        4500             21    94500
# ...

# %%
df.sort_index()
#Sort the index of a DataFrame
# Out:
#      products  unit_price  quantity_sold  revenue
# 0        rice        1400             85   119000
# 1       garri        4000             65   260000
# 2        semo         800             30    24000
# 3         yam        2000             60   120000
# 4       beans        1200             45    54000
# 5       bread        1500            150   225000
# 6    potatoes        1200             80    96000
# 7   plaintain         500             24    12000
# 8     cocoyam        3500             30   105000
# 9        milo        1800             81   145800
# 10    cowbell        1500             75   112500
# 11  bournvita        2500             65   162500
# 12      pepsi        3200             95   304000
# 13        egg        3400             48   163200
# 14   tomatoes        6000             59   354000
# 15     pepper        6500             63   409500
# 16       malt        4500             21    94500
# 17       coke        3500             80   280000
# ...

# %%
df.reset_index()
#Reset index of DataFrame to row numbers, moving index to columns.
# Out:
#     index   products  unit_price  quantity_sold  revenue
# 0       0       rice        1400             85   119000
# 1       1      garri        4000             65   260000
# 2       2       semo         800             30    24000
# 3       3        yam        2000             60   120000
# 4       4      beans        1200             45    54000
# 5       5      bread        1500            150   225000
# 6       6   potatoes        1200             80    96000
# 7       7  plaintain         500             24    12000
# 8       8    cocoyam        3500             30   105000
# 9       9       milo        1800             81   145800
# 10     10    cowbell        1500             75   112500
# 11     11  bournvita        2500             65   162500
# 12     12      pepsi        3200             95   304000
# 13     13        egg        3400             48   163200
# 14     14   tomatoes        6000             59   354000
# ...

# %%
df.drop(columns=['quantity_sold','revenue'])
#Drop columns from DataFrame
# Out:
#      products  unit_price
# 0        rice        1400
# 1       garri        4000
# 2        semo         800
# 3         yam        2000
# 4       beans        1200
# 5       bread        1500
# 6    potatoes        1200
# 7   plaintain         500
# 8     cocoyam        3500
# 9        milo        1800
# 10    cowbell        1500
# 11  bournvita        2500
# 12      pepsi        3200
# 13        egg        3400
# 14   tomatoes        6000
# 15     pepper        6500
# 16       malt        4500
# 17       coke        3500
# 18      maize       15000
# 19       fish       10500
# 20   goatmeat       25000

# %% [markdown]
# # Subset Observations - rows

# %%
df[df.revenue < 50000] #Extract rows that meet logical criteria
# Out:
#     products  unit_price  quantity_sold  revenue
# 2       semo         800             30    24000
# 7  plaintain         500             24    12000

# %%
df.drop_duplicates()  #Remove duplicate rows (only considers columns)
# Out:
#      products  unit_price  quantity_sold  revenue
# 0        rice        1400             85   119000
# 1       garri        4000             65   260000
# 2        semo         800             30    24000
# 3         yam        2000             60   120000
# 4       beans        1200             45    54000
# 5       bread        1500            150   225000
# 6    potatoes        1200             80    96000
# 7   plaintain         500             24    12000
# 8     cocoyam        3500             30   105000
# 9        milo        1800             81   145800
# 10    cowbell        1500             75   112500
# 11  bournvita        2500             65   162500
# 12      pepsi        3200             95   304000
# 13        egg        3400             48   163200
# 14   tomatoes        6000             59   354000
# 15     pepper        6500             63   409500
# 16       malt        4500             21    94500
# 17       coke        3500             80   280000
# ...

# %%
df.sample(frac=0.5) #Randomly select fraction of rows
# Out:
#      products  unit_price  quantity_sold  revenue
# 0        rice        1400             85   119000
# 10    cowbell        1500             75   112500
# 19       fish       10500             50   525000
# 16       malt        4500             21    94500
# 3         yam        2000             60   120000
# 7   plaintain         500             24    12000
# 13        egg        3400             48   163200
# 6    potatoes        1200             80    96000
# 2        semo         800             30    24000
# 4       beans        1200             45    54000

# %%
df.sample(n=3) #Randomly select n rows
# Out:
#    products  unit_price  quantity_sold  revenue
# 17     coke        3500             80   280000
# 9      milo        1800             81   145800
# 5     bread        1500            150   225000

# %%
df.nlargest(5, 'quantity_sold') #Select and order top n entries
# Out:
#     products  unit_price  quantity_sold  revenue
# 5      bread        1500            150   225000
# 12     pepsi        3200             95   304000
# 0       rice        1400             85   119000
# 9       milo        1800             81   145800
# 6   potatoes        1200             80    96000

# %%
df.nsmallest(3, 'unit_price') #Select and order bottom n entries
# Out:
#     products  unit_price  quantity_sold  revenue
# 7  plaintain         500             24    12000
# 2       semo         800             30    24000
# 4      beans        1200             45    54000

# %%
df.head(3) #Select first n rows.
# Out:
#   products  unit_price  quantity_sold  revenue
# 0     rice        1400             85   119000
# 1    garri        4000             65   260000
# 2     semo         800             30    24000

# %%
df.tail(3) #Select last n rows.
# Out:
#     products  unit_price  quantity_sold  revenue
# 18     maize       15000             25   375000
# 19      fish       10500             50   525000
# 20  goatmeat       25000             35   875000

# %% [markdown]
# # Subset Variables - columns

# %%
df[['products','revenue']] #Select multiple columns with specific names
# Out:
#      products  revenue
# 0        rice   119000
# 1       garri   260000
# 2        semo    24000
# 3         yam   120000
# 4       beans    54000
# 5       bread   225000
# 6    potatoes    96000
# 7   plaintain    12000
# 8     cocoyam   105000
# 9        milo   145800
# 10    cowbell   112500
# 11  bournvita   162500
# 12      pepsi   304000
# 13        egg   163200
# 14   tomatoes   354000
# 15     pepper   409500
# 16       malt    94500
# 17       coke   280000
# 18      maize   375000
# 19       fish   525000
# 20   goatmeat   875000

# %% [markdown]
# # Subsets - rows and columns

# %%
df.loc[1]
# Out:
# products          garri
# unit_price         4000
# quantity_sold        65
# revenue          260000
# Name: 1, dtype: object

# %%
df.iloc[5]
# Out:
# products          bread
# unit_price         1500
# quantity_sold       150
# revenue          225000
# Name: 5, dtype: object

# %%
df.products[0]
# Out:
# 'rice'

# %%
df.iloc[15:20] #Select rows 15 to 19, row 20 will be excluded.
# Out:
#    products  unit_price  quantity_sold  revenue
# 15   pepper        6500             63   409500
# 16     malt        4500             21    94500
# 17     coke        3500             80   280000
# 18    maize       15000             25   375000
# 19     fish       10500             50   525000

# %%
df.loc[df['revenue'] > 280000, ['products', 'unit_price']]  #Select rows meeting logical condition, and only the specific columns .
# Out:
#     products  unit_price
# 12     pepsi        3200
# 14  tomatoes        6000
# 15    pepper        6500
# 18     maize       15000
# 19      fish       10500
# 20  goatmeat       25000

# %% [markdown]
# # Using query

# %%
df.query('quantity_sold > 80')
# Out:
#    products  unit_price  quantity_sold  revenue
# 0      rice        1400             85   119000
# 5     bread        1500            150   225000
# 9      milo        1800             81   145800
# 12    pepsi        3200             95   304000

# %%
df.query('unit_price > 24 and quantity_sold < 45')
# Out:
#      products  unit_price  quantity_sold  revenue
# 2        semo         800             30    24000
# 7   plaintain         500             24    12000
# 8     cocoyam        3500             30   105000
# 16       malt        4500             21    94500
# 18      maize       15000             25   375000
# 20   goatmeat       25000             35   875000

# %% [markdown]
# # summarizing data

# %%
df['unit_price'].value_counts()  #Count number of rows with each unique value of variable
# Out:
# unit_price
# 1200     2
# 1500     2
# 3500     2
# 1400     1
# 3400     1
# 10500    1
# 15000    1
# 4500     1
# 6500     1
# 6000     1
# 2500     1
# 3200     1
# 4000     1
# 1800     1
# 500      1
# 2000     1
# 800      1
# 25000    1
# Name: count, dtype: int64

# %%
len(df)
# of rows in DataFrame
# Out:
# 21

# %%
df.shape  #no of rows and of columns in a DataFrame
# Out:
# (21, 4)

# %%
df['products'].nunique()  # of distinct values in a column
# Out:
# 21

# %%
df.describe()  #Basic descriptive and statistics for each colum
# Out:
#          unit_price  quantity_sold        revenue
# count     21.000000      21.000000      21.000000
# mean    4738.095238      60.285714  229333.333333
# std     5802.281981      30.339978  200969.593057
# min      500.000000      21.000000   12000.000000
# 25%     1500.000000      35.000000  105000.000000
# 50%     3200.000000      60.000000  162500.000000
# 75%     4500.000000      80.000000  304000.000000
# max    25000.000000     150.000000  875000.000000

# %%
df.dropna()  #Drop rows with any column having NA/null data.
# Out:
#      products  unit_price  quantity_sold  revenue
# 0        rice        1400             85   119000
# 1       garri        4000             65   260000
# 2        semo         800             30    24000
# 3         yam        2000             60   120000
# 4       beans        1200             45    54000
# 5       bread        1500            150   225000
# 6    potatoes        1200             80    96000
# 7   plaintain         500             24    12000
# 8     cocoyam        3500             30   105000
# 9        milo        1800             81   145800
# 10    cowbell        1500             75   112500
# 11  bournvita        2500             65   162500
# 12      pepsi        3200             95   304000
# 13        egg        3400             48   163200
# 14   tomatoes        6000             59   354000
# 15     pepper        6500             63   409500
# 16       malt        4500             21    94500
# 17       coke        3500             80   280000
# ...

# %%
df.fillna(100) #Replace all NA/null data with value
# Out:
#      products  unit_price  quantity_sold  revenue
# 0        rice        1400             85   119000
# 1       garri        4000             65   260000
# 2        semo         800             30    24000
# 3         yam        2000             60   120000
# 4       beans        1200             45    54000
# 5       bread        1500            150   225000
# 6    potatoes        1200             80    96000
# 7   plaintain         500             24    12000
# 8     cocoyam        3500             30   105000
# 9        milo        1800             81   145800
# 10    cowbell        1500             75   112500
# 11  bournvita        2500             65   162500
# 12      pepsi        3200             95   304000
# 13        egg        3400             48   163200
# 14   tomatoes        6000             59   354000
# 15     pepper        6500             63   409500
# 16       malt        4500             21    94500
# 17       coke        3500             80   280000
# ...

# %% [markdown]
# # windows

# %%
df.expanding()
# Out:
# Expanding [min_periods=1,axis=0,method=single]

# %%
df.rolling(5)
# Out:
# Rolling [window=5,center=False,axis=0,method=single]

# %% [markdown]
# ## plotting

# %%
df.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot.scatter(x='quantity_sold',y='revenue')
# Out:
# <Axes: xlabel='quantity_sold', ylabel='revenue'>
